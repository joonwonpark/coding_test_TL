# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/43164

# %% [markdown]
# ![image.png](attachment:68bdb2e2-722a-4c96-b900-15c0478d8676.png)

# %%
def solution(tickets):
    answer = []
    return answer

# %%
def dfs(graph, v, visited):
    visited[v] = True
    for i in graph[v]:
        if not visited[v]:
            dfs(graph, i, visited)

# %%
tickets = [["ICN", "JFK"], ["HND", "IAD"], ["JFK", "HND"]]

# %%
dir(ticket_map)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
num = 0
ticket_map = {}
for i in tickets:
    for j in range(2):
        if i[j] not in ticket_map:
            ticket_map[i[j]] = num
            num += 1

# %%
ticket_map
# Out:
# {'ICN': 0, 'JFK': 1, 'HND': 2, 'IAD': 3}

# %%
node_dict = {}
node_dict['ICN'] = 1
    for i, word in enumerate(words):
        node_dict[word] = i + 1

# %%
graph= [[]]
for i
