# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/72410?language=python3

# %% [markdown]
# ![image.png](attachment:d44a8460-b125-441c-b473-b47506201b81.png)

# %% [markdown]
# ![image.png](attachment:b87cfaa3-6fdb-4745-ab7f-eecf417ad432.png)
